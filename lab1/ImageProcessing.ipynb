# %% [markdown]
# <a href="https://colab.research.google.com/github/giivanov/image-processing/blob/main/lab1/ImageProcessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-a95993fe-25d0-4f37-8d07-528d050a6f25" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a95993fe-25d0-4f37-8d07-528d050a6f25">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving gray.jpg to gray.jpg
# Saving cube.jpg to cube.jpg
# Saving color.jpg to color.jpg
# User uploaded file "gray.jpg" with length 110895 bytes
# User uploaded file "cube.jpg" with length 18955 bytes
# User uploaded file "color.jpg" with length 48235 bytes

# %%
import numpy as np

# %%
a = np.array([1, 2, 3])
print(a)
# Out:
# [1 2 3]

# %%
m = np.random.randint(low=10, high=20, size=(2, 4))
# Out:
# array([[17, 13, 16, 16],
#        [13, 14, 16, 12]])

# %%
np.sum(m)
# Out:
# 117

# %%
v = np.array([1, 2, 3, 4, 5])

# %%
np.cumsum(v)
# Out:
# array([ 1,  3,  6, 10, 15])

# %%
np.shape(v)
# Out:
# (5,)

# %%
v1 = np.zeros(v.shape)
v1
# Out:
# array([0., 0., 0., 0., 0.])

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
v1[0] = v[0]
for i in range(1, np.shape(v)[0]):
  v1[i] = v[i] + v1[i-1]
v1
# Out:
# array([ 1.,  3.,  6., 10., 15.])

# %%
m = np.ones((3, 4))
(r, c) = m.shape
print(r, c)
# Out:
# 3 4

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(v1)

# %%
import cv2

# %%
# inp = cv2.imread("cube.jpg", cv2.IMREAD_GRAYSCALE)
inp = cv2.imread("cube.jpg")

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(inp)
# Out:
# <PIL.Image.Image image mode=L size=476x268 at 0x7F3F1DBC2908>

# %%
plt.figure(1)

# %%
plt.imshow(inp) # no cmap, uses the default :/

# %%
inp1 = cv2.cvtColor(inp, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(inp1)

# %%
inp = cv2.imread("cube.jpg", cv2.IMREAD_GRAYSCALE)
plt.imshow(inp, 'gray')

# %%
input = cv2.imread("gray.jpg", cv2.IMREAD_GRAYSCALE)

# %%
dst = cv2.equalizeHist(input)

# %%
plt.imshow(input, 'gray')

# %%
plt.imshow(dst, 'gray')

# %%
plt.figure(1)
plt.subplot(121)
plt.imshow(input, 'gray')
plt.subplot(122)
plt.imshow(dst, 'gray')

# %%
input_hist = np.histogram(input)
